# %%
# standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# modeling imports
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
dftrn = pd.read_csv('../data/train.csv')
dftst = pd.read_csv('../data/test.csv')
dftrn['Alley'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Alley, dtype: object

# %%
dftrn.dtypes
# Out:
# Id                int64
# PID               int64
# MS SubClass       int64
# MS Zoning        object
# Lot Frontage    float64
#                  ...
# Misc Val          int64
# Mo Sold           int64
# Yr Sold           int64
# Sale Type        object
# SalePrice         int64
# Length: 81, dtype: object

# %%
# Calculate number rows in both Train and Test Data
dftrn_Nof_rows = len(dftrn.index)
dftst_Nof_rows = len(dftst.index)
print(dftrn_Nof_rows)
print(dftst_Nof_rows)
# Out:
# 2051
# 879

# %%
dftrn.info()
# dftst.info()
# dftrn.head()
# dftst.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
#  16  Bldg Type        2051 non-null   object
#  17  House Style      2051 non-null   object
#  18  Overall Qual     2051 non-null   int64
#  19  Overall Cond     2051 non-null   int64
#  20  Year Built       2051 non-null   int64
#  21  Year Remod/Add   2051 non-null   int64
#  22  Roof Style       2051 non-null   object
#  23  Roof Matl        2051 non-null   object
#  24  Exterior 1st     2051 non-null   object
#  25  Exterior 2nd     2051 non-null   object
#  26  Mas Vnr Type     2029 non-null   object
#  27  Mas Vnr Area     2029 non-null   float64
#  28  Exter Qual       2051 non-null   object
#  29  Exter Cond       2051 non-null   object
#  30  Foundation       2051 non-null   object
#  31  Bsmt Qual        1996 non-null   object
#  32  Bsmt Cond        1996 non-null   object
#  33  Bsmt Exposure    1993 non-null   object
#  34  BsmtFin Type 1   1996 non-null   object
#  35  BsmtFin SF 1     2050 non-null   float64
#  36  BsmtFin Type 2   1995 non-null   object
#  37  BsmtFin SF 2     2050 non-null   float64
#  38  Bsmt Unf SF      2050 non-null   float64
#  39  Total Bsmt SF    2050 non-null   float64
#  40  Heating          2051 non-null   object
#  41  Heating QC       2051 non-null   object
#  42  Central Air      2051 non-null   object
#  43  Electrical       2051 non-null   object
#  44  1st Flr SF       2051 non-null   int64
#  45  2nd Flr SF       2051 non-null   int64
#  46  Low Qual Fin SF  2051 non-null   int64
#  47  Gr Liv Area      2051 non-null   int64
#  48  Bsmt Full Bath   2049 non-null   float64
#  49  Bsmt Half Bath   2049 non-null   float64
#  50  Full Bath        2051 non-null   int64
#  51  Half Bath        2051 non-null   int64
#  52  Bedroom AbvGr    2051 non-null   int64
#  53  Kitchen AbvGr    2051 non-null   int64
#  54  Kitchen Qual     2051 non-null   object
#  55  TotRms AbvGrd    2051 non-null   int64
#  56  Functional       2051 non-null   object
#  57  Fireplaces       2051 non-null   int64
#  58  Fireplace Qu     1051 non-null   object
#  59  Garage Type      1938 non-null   object
#  60  Garage Yr Blt    1937 non-null   float64
#  61  Garage Finish    1937 non-null   object
#  62  Garage Cars      2050 non-null   float64
#  63  Garage Area      2050 non-null   float64
#  64  Garage Qual      1937 non-null   object
#  65  Garage Cond      1937 non-null   object
#  66  Paved Drive      2051 non-null   object
#  67  Wood Deck SF     2051 non-null   int64
#  68  Open Porch SF    2051 non-null   int64
#  69  Enclosed Porch   2051 non-null   int64
#  70  3Ssn Porch       2051 non-null   int64
#  71  Screen Porch     2051 non-null   int64
#  72  Pool Area        2051 non-null   int64
#  73  Pool QC          9 non-null      object
#  74  Fence            400 non-null    object
#  75  Misc Feature     65 non-null     object
#  76  Misc Val         2051 non-null   int64
#  77  Mo Sold          2051 non-null   int64
#  78  Yr Sold          2051 non-null   int64
#  79  Sale Type        2051 non-null   object
#  80  SalePrice        2051 non-null   int64
# dtypes: float64(11), int64(28), object(42)
# memory usage: 1.3+ MB

# %%
dftrn_Null = dftrn.isnull().sum()
dftst_Null = dftst.isnull().sum()
dftrn_Zero = dftrn.isin([0]).sum()
dftst_Zero = dftst.isin([0]).sum()
dftrn_Zero = (dftrn == 0 ).sum()
dftst_Zero = (dftst == 0 ).sum()
dftst_Zero.tail(30)
# Out:
# Full Bath           4
# Half Bath         535
# Bedroom AbvGr       3
# Kitchen AbvGr       1
# Kitchen Qual        0
# TotRms AbvGrd       0
# Functional          0
# Fireplaces        422
# Fireplace Qu        0
# Garage Type         0
# Garage Yr Blt       0
# Garage Finish       0
# Garage Cars        44
# Garage Area        44
# Garage Qual         0
# Garage Cond         0
# Paved Drive         0
# Wood Deck SF      451
# Open Porch SF     388
# Enclosed Porch    747
# 3Ssn Porch        868
# Screen Porch      804
# Pool Area         875
# Pool QC             0
# Fence               0
# Misc Feature        0
# Misc Val          841
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# dtype: int64

# %%
dftrn_Zero
# Out:
# Id                 0
# PID                0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage       0
#                 ...
# Misc Val        1986
# Mo Sold            0
# Yr Sold            0
# Sale Type          0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# dataframe for data 
df_EC = pd.DataFrame(dftrn_Null,columns=['No_train_null'])
df_EC['No_test_null'] = dftst_Null
df_EC['train_null_%'] = round(100*df_EC['No_train_null']/dftrn_Nof_rows,2)
df_EC['test_null_%'] = round(100*df_EC['No_test_null']/dftst_Nof_rows,2)
df_EC['train_unique'] = dftrn.nunique()
df_EC['test_unique'] = dftst.nunique()
df_EC['train_zero'] = dftrn_Zero
df_EC['test_zero'] = dftst_Zero
df_EC['train_zero_%'] = round(100*df_EC['train_zero']/dftrn_Nof_rows,2)
df_EC['test_zero_%'] = round(100*df_EC['test_zero']/dftst_Nof_rows,2)
df_EC['train_type'] = dftst.dtypes
df_EC['test_type'] = dftrn.dtypes
df_EC.tail(30)
# Out:
#                 No_train_null  No_test_null  train_null_%  test_null_%  \
# Half Bath                   0           0.0          0.00         0.00
# Bedroom AbvGr               0           0.0          0.00         0.00
# Kitchen AbvGr               0           0.0          0.00         0.00
# Kitchen Qual                0           0.0          0.00         0.00
# TotRms AbvGrd               0           0.0          0.00         0.00
# Functional                  0           0.0          0.00         0.00
# Fireplaces                  0           0.0          0.00         0.00
# Fireplace Qu             1000         422.0         48.76        48.01
# Garage Type               113          44.0          5.51         5.01
# Garage Yr Blt             114          45.0          5.56         5.12
# Garage Finish             114          45.0          5.56         5.12
# Garage Cars                 1           0.0          0.05         0.00
# Garage Area                 1           0.0          0.05         0.00
# Garage Qual               114          45.0          5.56         5.12
# Garage Cond               114          45.0          5.56         5.12
# Paved Drive                 0           0.0          0.00         0.00
# Wood Deck SF                0           0.0          0.00         0.00
# Open Porch SF               0           0.0          0.00         0.00
# Enclosed Porch              0           0.0          0.00         0.00
# 3Ssn Porch                  0           0.0          0.00         0.00
# Screen Porch                0           0.0          0.00         0.00
# Pool Area                   0           0.0          0.00         0.00
# Pool QC                  2042         875.0         99.56        99.54
# Fence                    1651         707.0         80.50        80.43
# Misc Feature             1986         838.0         96.83        95.34
# Misc Val                    0           0.0          0.00         0.00
# Mo Sold                     0           0.0          0.00         0.00
# Yr Sold                     0           0.0          0.00         0.00
# Sale Type                   0           0.0          0.00         0.00
# SalePrice                   0           NaN          0.00          NaN
#
#                 train_unique  test_unique  train_zero  test_zero  \
# Half Bath                  3          3.0        1308      535.0
# Bedroom AbvGr              8          7.0           5        3.0
# Kitchen AbvGr              4          4.0           2        1.0
# Kitchen Qual               4          5.0           0        0.0
# TotRms AbvGrd             14         10.0           0        0.0
# Functional                 8          6.0           0        0.0
# Fireplaces                 5          4.0        1000      422.0
# Fireplace Qu               5          5.0           0        0.0
# Garage Type                6          6.0           0        0.0
# Garage Yr Blt            100         93.0           0        0.0
# Garage Finish              3          3.0           0        0.0
# Garage Cars                6          5.0         113       44.0
# Garage Area              514        357.0         113       44.0
# Garage Qual                5          4.0           0        0.0
# Garage Cond                5          5.0           0        0.0
# Paved Drive                3          3.0           0        0.0
# Wood Deck SF             322        210.0        1075      451.0
# Open Porch SF            223        163.0         912      388.0
# Enclosed Porch           159         83.0        1724      747.0
# 3Ssn Porch                22         12.0        2025      868.0
# Screen Porch             100         54.0        1870      804.0
# Pool Area                 10          5.0        2042      875.0
# Pool QC                    4          2.0           0        0.0
# Fence                      4          4.0           0        0.0
# Misc Feature               5          3.0           0        0.0
# Misc Val                  28         21.0        1986      841.0
# Mo Sold                   12         12.0           0        0.0
# Yr Sold                    5          5.0           0        0.0
# Sale Type                  9         10.0           0        0.0
# SalePrice                828          NaN           0        NaN
#
#                 train_zero_%  test_zero_% train_type test_type
# Half Bath              63.77        60.86      int64     int64
# Bedroom AbvGr           0.24         0.34      int64     int64
# Kitchen AbvGr           0.10         0.11      int64     int64
# Kitchen Qual            0.00         0.00     object    object
# TotRms AbvGrd           0.00         0.00      int64     int64
# Functional              0.00         0.00     object    object
# Fireplaces             48.76        48.01      int64     int64
# Fireplace Qu            0.00         0.00     object    object
# Garage Type             0.00         0.00     object    object
# Garage Yr Blt           0.00         0.00    float64   float64
# Garage Finish           0.00         0.00     object    object
# Garage Cars             5.51         5.01    float64   float64
# Garage Area             5.51         5.01    float64   float64
# Garage Qual             0.00         0.00     object    object
# Garage Cond             0.00         0.00     object    object
# Paved Drive             0.00         0.00     object    object
# Wood Deck SF           52.41        51.31      int64     int64
# Open Porch SF          44.47        44.14      int64     int64
# Enclosed Porch         84.06        84.98      int64     int64
# 3Ssn Porch             98.73        98.75      int64     int64
# Screen Porch           91.18        91.47      int64     int64
# Pool Area              99.56        99.54      int64     int64
# Pool QC                 0.00         0.00     object    object
# Fence                   0.00         0.00     object    object
# Misc Feature            0.00         0.00     object    object
# Misc Val               96.83        95.68      int64     int64
# Mo Sold                 0.00         0.00      int64     int64
# Yr Sold                 0.00         0.00      int64     int64
# Sale Type               0.00         0.00     object    object
# SalePrice               0.00          NaN        NaN     int64

# %%
# df_EC[df_EC['train_null_Pct'] > 0]
# df_EC[df_EC['train_unique'] < 10]
# print(df_EC[df_EC['train_type'] == 'object'])
# len(df_EC[df_EC['train_type'] == 'object'])

# %%
Null_list = list(df_EC[df_EC['train_null_%'] > 50].index)
drop_columns = Null_list
print(drop_columns)
print(len(drop_columns))

Zero_list = list(df_EC[df_EC['train_zero_%'] > 40].index)
drop_columns = drop_columns + Zero_list
print(drop_columns)
print(len(drop_columns))

Zero_list = list(df_EC[df_EC['train_type'] == 'object'].index)
drop_columns = drop_columns + Zero_list
print(drop_columns)
print(len(drop_columns))
# Out:
# ['Alley', 'Pool QC', 'Fence', 'Misc Feature']
# 4
# ['Alley', 'Pool QC', 'Fence', 'Misc Feature', 'Mas Vnr Area', 'BsmtFin SF 2', '2nd Flr SF', 'Low Qual Fin SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Half Bath', 'Fireplaces', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val']
# 19
# ['Alley', 'Pool QC', 'Fence', 'Misc Feature', 'Mas Vnr Area', 'BsmtFin SF 2', '2nd Flr SF', 'Low Qual Fin SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Half Bath', 'Fireplaces', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val', 'MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Kitchen Qual', 'Functional', 'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature', 'Sale Type']
# 61

# %%
dftrn.drop(drop_columns,axis=1,inplace=True)
dftst.drop(drop_columns,axis=1,inplace=True)
# df_EC.drop(drop_columns,inplace=True)

# %%
print(dftrn.columns)
len(dftrn.columns)
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'BsmtFin SF 1',
#        'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF', 'Gr Liv Area',
#        'Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd',
#        'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Mo Sold', 'Yr Sold',
#        'SalePrice'],
#       dtype='object')
# 24

# %%
EDA_List1 = list(dftrn.columns[2:7]) + ['SalePrice']
EDA_List2 = list(dftrn.columns[8:13]) + ['SalePrice']
EDA_List3 = list(dftrn.columns[14:19]) + ['SalePrice']
EDA_List4 = list(dftrn.columns[20:23]) + ['SalePrice']
print(EDA_List1)
print(EDA_List2)
print(EDA_List3)
print(EDA_List4)
# Out:
# ['MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond', 'SalePrice']
# ['Year Remod/Add', 'BsmtFin SF 1', 'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF', 'SalePrice']
# ['Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Garage Yr Blt', 'SalePrice']
# ['Garage Area', 'Mo Sold', 'Yr Sold', 'SalePrice']

# %% [markdown]
# ### EDA : Plot 1

# %%
# sns.pairplot(dftrn[['MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual','Overall Cond', 'Year Built','SalePrice']])
sns.pairplot(dftrn[EDA_List1])

# %%
sns.heatmap(dftrn[EDA_List1].corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dftrn[EDA_List2])

# %%
sns.heatmap(dftrn[EDA_List2].corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dftrn[EDA_List3])

# %%
sns.heatmap(dftrn[EDA_List3].corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dftrn[EDA_List4])

# %%
sns.heatmap(dftrn[EDA_List4].corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
print(EDA_List1)
print(EDA_List2)
print(EDA_List3)
print(EDA_List4)
# Out:
# ['MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond', 'SalePrice']
# ['Year Remod/Add', 'BsmtFin SF 1', 'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF', 'SalePrice']
# ['Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Garage Yr Blt', 'SalePrice']
# ['Garage Area', 'Mo Sold', 'Yr Sold', 'SalePrice']

# %%
# df = dftrn[['Lot Area','Garage Area','Full Bath','Garage Yr Blt','TotRms AbvGrd','Year Remod/Add']]
# df.head()

# %%
# np.any(np.isnan(df))

# %%
# df.isnull().sum()
# df['Garage Area'] == 0
# df.isnull().any()

# %%
# df = df.fillna(0)

# %%
# np.any(np.isnan(df))

# %%
# df.isnull().any()

# %%
# df['Garage Area'].astype('int')
# df['Garage Area'].dtype

# %%
# df.info()

# %%
# df.isnull().sum()

# %%
# df = df.replace([np.inf, -np.inf], np.nan)
# df.isnull().sum()

# %%
# df['Garage Area'] = df['Garage Area'].map(lambda x : float(x)/1)
# df['Garage Area'] = df['Garage Area'].map(lambda x : int(x))
# df['Garage Yr Blt'] = df['Garage Yr Blt'].map(lambda x : int(x))
# df.replace(0, np.nan, inplace=True)
#act17['Participation'] = act17['Participation'].map(lambda x : float(x.replace('%','')))
# act17_web['Participation'].map(lambda x : float(x)/100)

# %%
# df.isnull().sum()

# %%
# df = df.fillna(0)

# %%
# df.isnull().sum()

# %%
# df.info()

# %%
# df['Garage Area'] = df['Garage Area'].map(lambda x : float(x))

# %% [markdown]
# ### Start New

# %%
df1 = pd.read_csv('../data/train.csv')
df2 = pd.read_csv('../data/test.csv')

# %%
print(drop_columns)
print(len(drop_columns))
# Out:
# ['Alley', 'Pool QC', 'Fence', 'Misc Feature', 'Mas Vnr Area', 'BsmtFin SF 2', '2nd Flr SF', 'Low Qual Fin SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Half Bath', 'Fireplaces', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val', 'MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Kitchen Qual', 'Functional', 'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature', 'Sale Type']
# 61

# %%
df1.drop(drop_columns,axis=1,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              2051 non-null   int64
#  1   PID             2051 non-null   int64
#  2   MS SubClass     2051 non-null   int64
#  3   Lot Frontage    1721 non-null   float64
#  4   Lot Area        2051 non-null   int64
#  5   Overall Qual    2051 non-null   int64
#  6   Overall Cond    2051 non-null   int64
#  7   Year Built      2051 non-null   int64
#  8   Year Remod/Add  2051 non-null   int64
#  9   BsmtFin SF 1    2050 non-null   float64
#  10  Bsmt Unf SF     2050 non-null   float64
#  11  Total Bsmt SF   2050 non-null   float64
#  12  1st Flr SF      2051 non-null   int64
#  13  Gr Liv Area     2051 non-null   int64
#  14  Full Bath       2051 non-null   int64
#  15  Bedroom AbvGr   2051 non-null   int64
#  16  Kitchen AbvGr   2051 non-null   int64
#  17  TotRms AbvGrd   2051 non-null   int64
#  18  Garage Yr Blt   1937 non-null   float64
#  19  Garage Cars     2050 non-null   float64
#  20  Garage Area     2050 non-null   float64
#  21  Mo Sold         2051 non-null   int64
#  22  Yr Sold         2051 non-null   int64
#  23  SalePrice       2051 non-null   int64
# dtypes: float64(7), int64(17)
# memory usage: 384.7 KB

# %%
# df1['Lot Area'].isnull().sum()
# df1['Garage Area'].isnull().sum()
df1.isnull().sum()
# Out:
# Id                  0
# PID                 0
# MS SubClass         0
# Lot Frontage      330
# Lot Area            0
# Overall Qual        0
# Overall Cond        0
# Year Built          0
# Year Remod/Add      0
# BsmtFin SF 1        1
# Bsmt Unf SF         1
# Total Bsmt SF       1
# 1st Flr SF          0
# Gr Liv Area         0
# Full Bath           0
# Bedroom AbvGr       0
# Kitchen AbvGr       0
# TotRms AbvGrd       0
# Garage Yr Blt     114
# Garage Cars         1
# Garage Area         1
# Mo Sold             0
# Yr Sold             0
# SalePrice           0
# dtype: int64

# %%
df1.head()
# Out:
#     Id        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0  109  533352170           60           NaN     13517             6
# 1  544  531379050           60          43.0     11492             7
# 2  153  535304180           20          68.0      7922             5
# 3  318  916386060           60          73.0      9802             5
# 4  255  906425045           50          82.0     14235             6
#
#    Overall Cond  Year Built  Year Remod/Add  BsmtFin SF 1  ...  Full Bath  \
# 0             8        1976            2005         533.0  ...          2
# 1             5        1996            1997         637.0  ...          2
# 2             7        1953            2007         731.0  ...          1
# 3             5        2006            2007           0.0  ...          2
# 4             8        1900            1993           0.0  ...          2
#
#    Bedroom AbvGr  Kitchen AbvGr  TotRms AbvGrd  Garage Yr Blt  Garage Cars  \
# 0              3              1              6         1976.0          2.0
# 1              4              1              8         1997.0          2.0
# 2              3              1              5         1953.0          1.0
# 3              3              1              7         2007.0          2.0
# 4              3              1              6         1957.0          2.0
#
#    Garage Area  Mo Sold  Yr Sold  SalePrice
# 0        475.0        3     2010     130500
# 1        559.0        4     2009     220000
# 2        246.0        1     2010     109000
# 3        400.0        4     2010     174000
# 4        484.0        3     2010     138500
#
# [5 rows x 24 columns]

# %%
# features = ['Lot Area','Garage Area']
# df1[features] = df1[features].fillna(0)
df1 = df1.fillna(0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              2051 non-null   int64
#  1   PID             2051 non-null   int64
#  2   MS SubClass     2051 non-null   int64
#  3   Lot Frontage    2051 non-null   float64
#  4   Lot Area        2051 non-null   int64
#  5   Overall Qual    2051 non-null   int64
#  6   Overall Cond    2051 non-null   int64
#  7   Year Built      2051 non-null   int64
#  8   Year Remod/Add  2051 non-null   int64
#  9   BsmtFin SF 1    2051 non-null   float64
#  10  Bsmt Unf SF     2051 non-null   float64
#  11  Total Bsmt SF   2051 non-null   float64
#  12  1st Flr SF      2051 non-null   int64
#  13  Gr Liv Area     2051 non-null   int64
#  14  Full Bath       2051 non-null   int64
#  15  Bedroom AbvGr   2051 non-null   int64
#  16  Kitchen AbvGr   2051 non-null   int64
#  17  TotRms AbvGrd   2051 non-null   int64
#  18  Garage Yr Blt   2051 non-null   float64
#  19  Garage Cars     2051 non-null   float64
#  20  Garage Area     2051 non-null   float64
#  21  Mo Sold         2051 non-null   int64
#  22  Yr Sold         2051 non-null   int64
#  23  SalePrice       2051 non-null   int64
# dtypes: float64(7), int64(17)
# memory usage: 384.7 KB

# %%
df1.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'BsmtFin SF 1',
#        'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF', 'Gr Liv Area',
#        'Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd',
#        'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Mo Sold', 'Yr Sold',
#        'SalePrice'],
#       dtype='object')

# %%
# features = ['Lot Area','Garage Area','Full Bath','Garage Yr Blt','TotRms AbvGrd','Year Remod/Add']
# features = ['Lot Area','Garage Area','Full Bath','Garage Yr Blt','TotRms AbvGrd','Year Remod/Add']
features = ['MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual',
       'Overall Cond', 'Year Built', 'Year Remod/Add', 'BsmtFin SF 1',
       'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF', 'Gr Liv Area',
       'Full Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd',
       'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Mo Sold', 'Yr Sold']
X = df1[features]
y = df1['SalePrice']

# %%
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-1.35176219e+02,  3.82575822e+01,  5.84103152e-01,  1.95451632e+04,
#         3.84553487e+03,  3.40178364e+02,  1.62779145e+02,  8.76048503e+00,
#        -1.17080430e+01,  1.81392152e+01,  5.24221920e+00,  4.59248866e+01,
#         1.44147486e+03, -7.62555419e+03, -1.84454179e+04,  3.83899211e+03,
#        -1.42668477e+01,  1.19079976e+04,  2.09563884e+01,  3.45053483e+02,
#        -6.30175254e+02])

# %%
lr.intercept_
# Out:
# 227775.7670666955

# %%
predictions = lr.predict(X)

# %%
residuals = y - predictions
residuals
# Out:
# 0      -55512.959511
# 1      -16326.537520
# 2      -17062.809957
# 3       20355.518643
# 4      -12843.377904
#             ...
# 2046    28250.830270
# 2047   -11031.786114
# 2048     2854.054348
# 2049    36437.603563
# 2050   -21838.546537
# Name: SalePrice, Length: 2051, dtype: float64

# %%
np.mean(residuals)
# Out:
# 1.3162707523971812e-10

# %%
plt.hist(residuals, bins = 20);

# %%
plt.scatter(predictions, residuals)
plt.axhline(0, color='red');

# %%
np.abs(residuals).mean()
# Out:
# 20866.887180542566

# %%
metrics.mean_absolute_error(y, predictions)
# Out:
# 20866.887180542602

# %%
rss = (residuals ** 2).sum()

# %%
# MSE by hand
rss / len(residuals)
# Out:
# 1130009571.463414

# %%
# MSE using sklearn
metrics.mean_squared_error(y, predictions)
# Out:
# 1130009571.463414

# %%
# R2 from model
lr.score(X, y)
# Out:
# 0.8200298505433607
